# %% [markdown]
# ### Abstract
#
# We find histologies associated with tissues containing NF1 somatic mutations in the COSMIC database. There are 21. We find all other gene somatic mutations for those histologies.  We assess the main predisposing gene to be the gene with the most mutation-sample pairs associated with the histology.  We find that 4 histologies are primarily associated with NF1.  We find that the mutation sites in NF1 observed to the 4 histologies each are associated with only a single histology. For MPNST, 3 genes are equally scored and Neurofibroma has a very high score for NF1. We find that each histology is associated with multiple mutation sites. For the NF1 mutation sites associated with each histology, we give FATHM score and PUBMED ID.

# %% [markdown]
# NOTE: All of the samples are taken from people with somatic mutations leading to cancer, so there is selection bias in the samples to that extent.
#
# TODO: Program-based search for variant type, affected pathways and clinical significance from NCBI.

# %% [markdown]
# ### Required packages

# %%
import os, re, time
import pandas as pd
import numpy as np

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ### Getting the COSMIC database of genome screens
#
# For development purposes we have downloaded the COSMIC database from their website.  We have also uploaded it as a ZIP file to private file syn20716008.  It has license and sharing conditions and is 10GB in size, which makes it difficult to Dockerize.  Let's assume you have downloaded the file and placed it in a folder, and that there is an environment variable NF2_DATA that points to that folder.  This file, uncompressed, takes about an hour to read on a laptop PC with 16GB of RAM and 45GB of paging space.  It takes about 10 minutes to read on a workstation with 32GB of RAM, Intel core i9 processor and solid state disk.

# %%
data_dir=os.getenv('NF2_DATA')
df=pd.read_csv(f'{data_dir}/CosmicGenomeScreensMutantExport.tsv', sep='\t')
df=df.loc[:,['Gene name','Mutation CDS', 'ID_sample', 'Primary histology']].dropna()
df.columns=['gene', 'mutation', 'sampleid', 'histology']

# %% [markdown]
# ### We find histologies associated with tissues containing NF1 somatic mutations in the COSMIC database

# %% [markdown]
# #### Remove Not Sure histologies

# %%
df=df[df.histology != 'other']

# %%
df=df[df.histology != 'NS']

# %% [markdown]
# #### Make another dataframe for just NF1 mutations

# %%
nf1=df[df.gene=='NF1']
dd=nf1.to_dict()

# %%
nf1_histologies=set([y for x,y in dd['histology'].items()])

# %% [markdown]
# #### There are 21

# %%
len(nf1_histologies)
# Out:
# 21

# %% [markdown]
# ### We find all other gene somatic mutations for those histologies

# %% [markdown]
# #### Get the list of tissue samples studied for NF1

# %%
nf1_samples=set([y for x,y in dd['sampleid'].items()])

# %% [markdown]
# #### Restrict the set of all mutations to those concerning NF1-related histologies and samples

# %%
def strip_gene(x):
    return x.split('_')[0] if '_' in x else x

# %%
df_nf1=df[df.histology.isin(nf1_histologies)]
df_nf1=df_nf1[df_nf1.sampleid.isin(nf1_samples)]
genes=df_nf1.gene.unique()
samples=df_nf1.sampleid.unique()
histologies=df_nf1.histology.unique()
M=df_nf1.values
f=np.vectorize(strip_gene)
M[:,0]=f(M[:,0])
W={histology:{} for gene, mutation, sample, histology in M}
for gene, mutation, sample, histology in M:
    W[histology][gene]={}
for gene, mutation, sample, histology in M:
    W[histology][gene][mutation]=set([])
for gene, mutation, sample, histology in M:
    W[histology][gene][mutation].add(sample)

# %% [markdown]
# ### We assess the main predisposing gene for each histology

# %% [markdown]
# #### Our scoring function is the gene with the most mutation-sample pairs associated with the histology

# %%
n=3

# %%
def score(mutation_samples):
    return sum([len(mutation_samples[x]) for x in mutation_samples])

# %%
causative = []
not_causative = []
for histology in W:
    TT=list(reversed(sorted([(score(W[histology][gene]),gene) for gene in W[histology]])))
    total_mutations=sum([x for x,y in TT])
    TT1=[(y,x/total_mutations) for x,y in TT]
    genes=[x for x,y in TT1]
    if 'NF1' in genes[0:n]:
        i=[i for i,x in enumerate(genes[0:20]) if x=='NF1'][0]
        if genes[0]=='NF1' or TT1[0][1]==TT1[i][1]:
            causative.append((histology, [x for x in TT1 if x[1]==TT1[0][1]]))
        else:
            not_causative.append(histology)
    else:
        not_causative.append(histology)

# %% [markdown]
# #### 17 histologies do not score as causing NF1

# %%
pd.DataFrame(not_causative, columns=['Not caused by NF1'])
# Out:
#                                     Not caused by NF1
# 0                                           carcinoma
# 1                                   lymphoid_neoplasm
# 2                             haematopoietic_neoplasm
# 3                                  malignant_melanoma
# 4                                              glioma
# 5                          carcinoid-endocrine_tumour
# 6                                        angiosarcoma
# 7                                             adenoma
# 8    primitive_neuroectodermal_tumour-medulloblastoma
# 9   Ewings_sarcoma-peripheral_primitive_neuroectod...
# 10                                       osteosarcoma
# 11                                   rhabdomyosarcoma
# 12                           fibroepithelial_neoplasm
# 13                                   germ_cell_tumour
# 14          low_malignant_potential_borderline_tumour
# 15                                       Wilms_tumour
# 16                                 pulmonary_blastoma

# %% [markdown]
# #### We find that 4 histologies are scored as causative for  NF1

# %%
rows=[]
for histo,L in causative:
    for (gene, score) in L:
        rows.append((score, gene, histo))
rows.sort()
rows=list(reversed(rows))

# %%
nf1_histologies=[x for x,y in causative]
pd.DataFrame(nf1_histologies, columns=['histology'])
# Out:
#                                   histology
# 0                          pheochromocytoma
# 1                             neuroblastoma
# 2  malignant_peripheral_nerve_sheath_tumour
# 3                              neurofibroma

# %%
n_nf1_histologies=len(nf1_histologies)
n_nf1_histologies
# Out:
# 4

# %% [markdown]
# ### For MPNST, 3 genes are equally scored and Neurofibroma has a very high score for NF1

# %%
pd.DataFrame(rows, columns=['score', 'gene', 'histology'])
# Out:
#       score    gene                                 histology
# 0  0.909091     NF1                              neurofibroma
# 1  0.222222  SAMD4A  malignant_peripheral_nerve_sheath_tumour
# 2  0.222222     NF1  malignant_peripheral_nerve_sheath_tumour
# 3  0.222222   EHBP1  malignant_peripheral_nerve_sheath_tumour
# 4  0.152838     NF1                          pheochromocytoma
# 5  0.046005     NF1                             neuroblastoma

# %% [markdown]
# ### Multiple NF1 mutation sites are associated with each histology

# %%
nf1_mutations={histology:[x for x in W[histology]['NF1']] for histology in nf1_histologies}

# %%
pd.DataFrame([(x, len(nf1_mutations[x]), ','.join(sorted(nf1_mutations[x]))) for x in nf1_mutations],
               columns=['histology', 'n_mutations', 'mutations'])
# Out:
#                                   histology  n_mutations  \
# 0                          pheochromocytoma           22
# 1                             neuroblastoma           17
# 2  malignant_peripheral_nerve_sheath_tumour            2
# 3                              neurofibroma           10
#
#                                            mutations
# 0  c.1398del,c.1400C>T,c.1448A>G,c.1466A>G,c.1658...
# 1  c.*2307C>A,c.1039C>T,c.1063-58G>A,c.1977G>T,c....
# 2                          c.6642-17G>A,c.6705-17G>A
# 3  c.1324_1331del,c.3043del,c.5565_5567del,c.5628...

# %% [markdown]
# ###  NF1 mutation sites are each observed for only a single histology

# %%
intersections=[]
for i in range(n_nf1_histologies):
    hist_i=nf1_histologies[i]
    W_i=nf1_mutations[hist_i]
    for j in range(i+1,n_nf1_histologies):
        hist_j=nf1_histologies[j]
        W_j=nf1_mutations[hist_j]
        intersection=[x for x in W_i if x in W_j]
        intersections.append((hist_i,len(W_i), hist_j, len(W_j), len(intersection)))

# %%
pd.DataFrame(intersections, columns=['hist A', '# Mutations A', 'hist B', '# MutationsB', '# Intersections'])
# Out:
#                                      hist A  # Mutations A  \
# 0                          pheochromocytoma             22
# 1                          pheochromocytoma             22
# 2                          pheochromocytoma             22
# 3                             neuroblastoma             17
# 4                             neuroblastoma             17
# 5  malignant_peripheral_nerve_sheath_tumour              2
#
#                                      hist B  # MutationsB  # Intersections
# 0                             neuroblastoma            17                0
# 1  malignant_peripheral_nerve_sheath_tumour             2                0
# 2                              neurofibroma            10                0
# 3  malignant_peripheral_nerve_sheath_tumour             2                0
# 4                              neurofibroma            10                0
# 5                              neurofibroma            10                0

# %% [markdown]
# ## Information from COSMIC and NCBI on each NF1 mutation associated with a histology

# %% [markdown]
# For the NF1 mutation sites associated with each histology, we manually gather and present the variant type, affected pathways and clinical significance.

# %%
cosmic=pd.read_csv(f'{data_dir}/CosmicGenomeScreensMutantExport.tsv', sep='\t')

# %%
def nf1_hist_mutation_info(hist):
    global cosmic, nf1_mutations
    L=nf1_mutations[hist]
    df = cosmic[cosmic['Primary histology']==hist]
    df = df[df['Mutation CDS'].isin(L)]
    df = df[['Mutation CDS',
       'Mutation AA', 'Mutation Description', 'Mutation zygosity', 
       'Mutation strand', 'SNP',
       'FATHMM prediction', 'FATHMM score',
       'Pubmed_PMID']]
    return df.drop_duplicates()

# %% [markdown]
# ### malignant_peripheral_nerve_sheath_tumour

# %%
nf1_hist_mutation_info('malignant_peripheral_nerve_sheath_tumour')
# Out:
#           Mutation CDS Mutation AA Mutation Description Mutation zygosity  \
# 17392781  c.6705-17G>A         p.?              Unknown               NaN
# 28568308  c.6642-17G>A         p.?              Unknown               NaN
#
#          Mutation strand SNP FATHMM prediction  FATHMM score  Pubmed_PMID
# 17392781               +   n           NEUTRAL       0.43648   26432421.0
# 28568308               +   n           NEUTRAL       0.43648   26432421.0

# %% [markdown]
# ### pheochromocytoma

# %%
nf1_hist_mutation_info('pheochromocytoma')
# Out:
#             Mutation CDS    Mutation AA     Mutation Description  \
# 51506          c.1448A>G        p.D483G  Substitution - Missense
# 51508          c.2474C>G        p.S825C  Substitution - Missense
# 607775         c.1398del    p.T467Hfs*6    Deletion - Frameshift
# 724772          c.663G>A        p.W221*  Substitution - Nonsense
# 902327         c.1400C>T        p.T467I  Substitution - Missense
# 936893         c.1658A>G        p.H553R  Substitution - Missense
# 2174733        c.2422del   p.L808Ffs*13    Deletion - Frameshift
# 2174745      c.6705-1G>T            p.?                  Unknown
# 2908333   c.6522_6523del  p.E2174Dfs*46    Deletion - Frameshift
# 4121999        c.1466A>G        p.Y489C  Substitution - Missense
# 6802594      c.6642-1G>T            p.?                  Unknown
# 8898545   c.1756_1759del   p.T586Vfs*18    Deletion - Frameshift
# 9606173        c.1700T>G        p.V567G  Substitution - Missense
# 9631463        c.7237C>T       p.Q2413*  Substitution - Nonsense
# 10515948       c.2461A>C        p.S821R  Substitution - Missense
# 11907911       c.2695T>G        p.L899V  Substitution - Missense
# 12438223        c.910C>T        p.R304*  Substitution - Nonsense
# 22557352        c.243G>A         p.W81*  Substitution - Nonsense
# 23232768       c.7300C>T       p.Q2434*  Substitution - Nonsense
# 24827521       c.4436del   p.F1479Sfs*4    Deletion - Frameshift
# 31903293  c.6585_6586del  p.E2195Dfs*46    Deletion - Frameshift
# 33697444       c.4373del   p.F1458Sfs*4    Deletion - Frameshift
#
#          Mutation zygosity Mutation strand SNP FATHMM prediction  \
# 51506                  het               +   n        PATHOGENIC
# 51508                  het               +   n        PATHOGENIC
# 607775                 het               +   n               NaN
# 724772                 het               +   n        PATHOGENIC
# 902327                 het               +   n        PATHOGENIC
# 936893                 het               +   n        PATHOGENIC
# 2174733                het               +   n               NaN
# 2174745                het               +   n        PATHOGENIC
# 2908333                NaN               +   n               NaN
# 4121999                het               +   n        PATHOGENIC
# 6802594                het               +   n        PATHOGENIC
# 8898545                het               +   n               NaN
# 9606173                het               +   n        PATHOGENIC
# 9631463                het               +   n        PATHOGENIC
# 10515948               het               +   n        PATHOGENIC
# 11907911               het               +   n        PATHOGENIC
# 12438223               het               +   n        PATHOGENIC
# 22557352               het               +   n        PATHOGENIC
# 23232768               het               +   n        PATHOGENIC
# 24827521               het               +   n               NaN
# 31903293               NaN               +   n               NaN
# 33697444               het               +   n               NaN
#
#           FATHMM score  Pubmed_PMID
# 51506          0.98235   23781326.0
# 51508          0.98167   23781326.0
# 607775             NaN   25545346.0
# 724772         0.99127   25545346.0
# 902327         0.97282   23781326.0
# 936893         0.99034   23781326.0
# 2174733            NaN   23781326.0
# 2174745        0.99689   25545346.0
# 2908333            NaN   25545346.0
# 4121999        0.96016   23781326.0
# 6802594        0.99689   25545346.0
# 8898545            NaN   25545346.0
# 9606173        0.98640   23781326.0
# 9631463        0.95597   25545346.0
# 10515948       0.99648   23781326.0
# 11907911       0.88144   23781326.0
# 12438223       0.85410   23781326.0
# 22557352       0.99127   25545346.0
# 23232768       0.95597   25545346.0
# 24827521           NaN   25545346.0
# 31903293           NaN   25545346.0
# 33697444           NaN   25545346.0

# %% [markdown]
# ### neuroblastoma

# %%
nf1_hist_mutation_info('neuroblastoma')
# Out:
#              Mutation CDS Mutation AA          Mutation Description  \
# 4147230      c.1063-58G>A         p.?                       Unknown
# 4475582         c.6691G>T    p.E2231*       Substitution - Nonsense
# 5184719      c.2001+39G>T         p.?                       Unknown
# 6271437        c.*2307C>A         p.?                       Unknown
# 8746460         c.1039C>T     p.Q347*       Substitution - Nonsense
# 10515955        c.1977G>T     p.R659=  Substitution - coding silent
# 11578764         c.910C>G     p.R304G       Substitution - Missense
# 11907901  c.4836-20659G>T         p.?                       Unknown
# 11932998        c.6628G>T    p.E2210*       Substitution - Nonsense
# 12614951        c.7501G>T    p.E2501*       Substitution - Nonsense
# 14232023      c.7126+2T>C         p.?                       Unknown
# 15386927        c.1039C>T     p.P347S       Substitution - Missense
# 17949560        c.7438G>T    p.E2480*       Substitution - Nonsense
# 18808644        c.7501G>T    p.E2501*       Substitution - Nonsense
# 21133830        c.7285C>T    p.R2429*       Substitution - Nonsense
# 23587429        c.1978A>T     p.K660*       Substitution - Nonsense
# 25535086      c.7189+2T>C         p.?                       Unknown
# 27682680  c.4773-20659G>T         p.?                       Unknown
# 33874733        c.7438G>T    p.E2480*       Substitution - Nonsense
# 34381775        c.7348C>T    p.R2450*       Substitution - Nonsense
#
#          Mutation zygosity Mutation strand SNP FATHMM prediction  \
# 4147230                NaN               +   n           NEUTRAL
# 4475582                NaN               +   n        PATHOGENIC
# 5184719                NaN               +   n           NEUTRAL
# 6271437                NaN               +   n           NEUTRAL
# 8746460                NaN               +   n        PATHOGENIC
# 10515955               NaN               +   n        PATHOGENIC
# 11578764               NaN               +   n        PATHOGENIC
# 11907901               NaN               +   n           NEUTRAL
# 11932998               NaN               +   n        PATHOGENIC
# 12614951               NaN               +   n        PATHOGENIC
# 14232023               NaN               +   n        PATHOGENIC
# 15386927               NaN               +   n           NEUTRAL
# 17949560               NaN               +   n        PATHOGENIC
# 18808644               NaN               +   n        PATHOGENIC
# 21133830               NaN               +   n        PATHOGENIC
# 23587429               NaN               +   n        PATHOGENIC
# 25535086               NaN               +   n        PATHOGENIC
# 27682680               NaN               +   n           NEUTRAL
# 33874733               NaN               +   n        PATHOGENIC
# 34381775               NaN               +   n        PATHOGENIC
#
#           FATHMM score  Pubmed_PMID
# 4147230        0.08494          NaN
# 4475582        0.99796   23334666.0
# 5184719        0.15611          NaN
# 6271437        0.03680          NaN
# 8746460        0.97489          NaN
# 10515955       0.84177          NaN
# 11578764       0.87910          NaN
# 11907901       0.11841   23334666.0
# 11932998       0.99796   23334666.0
# 12614951       0.99166          NaN
# 14232023       0.99429          NaN
# 15386927       0.25960   23334666.0
# 17949560       0.99166   23334666.0
# 18808644       0.99166   23334666.0
# 21133830       0.90666   23334666.0
# 23587429       0.95112          NaN
# 25535086       0.99429          NaN
# 27682680       0.11841   23334666.0
# 33874733       0.99166          NaN
# 34381775       0.90666   23334666.0

# %% [markdown]
# ### neurofibroma

# %%
nf1_hist_mutation_info('neuroblastoma')
# Out:
#              Mutation CDS Mutation AA          Mutation Description  \
# 4147230      c.1063-58G>A         p.?                       Unknown
# 4475582         c.6691G>T    p.E2231*       Substitution - Nonsense
# 5184719      c.2001+39G>T         p.?                       Unknown
# 6271437        c.*2307C>A         p.?                       Unknown
# 8746460         c.1039C>T     p.Q347*       Substitution - Nonsense
# 10515955        c.1977G>T     p.R659=  Substitution - coding silent
# 11578764         c.910C>G     p.R304G       Substitution - Missense
# 11907901  c.4836-20659G>T         p.?                       Unknown
# 11932998        c.6628G>T    p.E2210*       Substitution - Nonsense
# 12614951        c.7501G>T    p.E2501*       Substitution - Nonsense
# 14232023      c.7126+2T>C         p.?                       Unknown
# 15386927        c.1039C>T     p.P347S       Substitution - Missense
# 17949560        c.7438G>T    p.E2480*       Substitution - Nonsense
# 18808644        c.7501G>T    p.E2501*       Substitution - Nonsense
# 21133830        c.7285C>T    p.R2429*       Substitution - Nonsense
# 23587429        c.1978A>T     p.K660*       Substitution - Nonsense
# 25535086      c.7189+2T>C         p.?                       Unknown
# 27682680  c.4773-20659G>T         p.?                       Unknown
# 33874733        c.7438G>T    p.E2480*       Substitution - Nonsense
# 34381775        c.7348C>T    p.R2450*       Substitution - Nonsense
#
#          Mutation zygosity Mutation strand SNP FATHMM prediction  \
# 4147230                NaN               +   n           NEUTRAL
# 4475582                NaN               +   n        PATHOGENIC
# 5184719                NaN               +   n           NEUTRAL
# 6271437                NaN               +   n           NEUTRAL
# 8746460                NaN               +   n        PATHOGENIC
# 10515955               NaN               +   n        PATHOGENIC
# 11578764               NaN               +   n        PATHOGENIC
# 11907901               NaN               +   n           NEUTRAL
# 11932998               NaN               +   n        PATHOGENIC
# 12614951               NaN               +   n        PATHOGENIC
# 14232023               NaN               +   n        PATHOGENIC
# 15386927               NaN               +   n           NEUTRAL
# 17949560               NaN               +   n        PATHOGENIC
# 18808644               NaN               +   n        PATHOGENIC
# 21133830               NaN               +   n        PATHOGENIC
# 23587429               NaN               +   n        PATHOGENIC
# 25535086               NaN               +   n        PATHOGENIC
# 27682680               NaN               +   n           NEUTRAL
# 33874733               NaN               +   n        PATHOGENIC
# 34381775               NaN               +   n        PATHOGENIC
#
#           FATHMM score  Pubmed_PMID
# 4147230        0.08494          NaN
# 4475582        0.99796   23334666.0
# 5184719        0.15611          NaN
# 6271437        0.03680          NaN
# 8746460        0.97489          NaN
# 10515955       0.84177          NaN
# 11578764       0.87910          NaN
# 11907901       0.11841   23334666.0
# 11932998       0.99796   23334666.0
# 12614951       0.99166          NaN
# 14232023       0.99429          NaN
# 15386927       0.25960   23334666.0
# 17949560       0.99166   23334666.0
# 18808644       0.99166   23334666.0
# 21133830       0.90666   23334666.0
# 23587429       0.95112          NaN
# 25535086       0.99429          NaN
# 27682680       0.11841   23334666.0
# 33874733       0.99166          NaN
# 34381775       0.90666   23334666.0
